# %% [markdown]
# # DID THEFT INCREASE IN KITSILANO DURING THE PANDEMIC?

# %% [markdown]
# ## INTRODUCTION

# %% [markdown]
# A study co-authored by Simon Fraser University researchers found that theft-related crimes increased in wealthier neighbourhoods, such as Kitsilano, during the pandemic (Andresen & Hodgkinson, 2022). They suspect this is related to the decrease in theft around downtown and surrounding neighbourhoods, as businesses closed down and employees started working from home. We will explore whether the proportion of Vancouver theft crimes occuring in Kitsilano has increased during the pandemic. Our response variables would be the proportion of theft crimes in Kitsilano in 2018 and 2020. The location parameter would be the difference in proportions between the two years, while the scale parameter would be the standard deviation of that difference. We hypothesize an increase in theft crimes from 2018 to 2020.

# %% [markdown]
# We will use crime data from the Vancouver Police Department: https://geodash.vpd.ca/opendata/. Within the website, we're able to select a specific year and neighbourhood(s) to view data from. We selected crime data from all neighbourhoods during 2018 and 2020. Each tuple lists the type of crime, the date (across several columns), and the location it occurred. Theft-related crimes are classified as either "Theft of Vehicle", "Theft of Bicycle", "Theft from Vehicle", or "Other Theft" under the TYPE column. To find the proportions of theft crime in Kitsilano for a specific year, we'll first filter for all theft-related crimes in our dataset. Then, we find the number of theft crimes in Kitsilano by filtering NEIGHBOURHOOD=="Kitsilano", and divide that by the total number of theft crimes across all neighbourhoods that year.

# %% [markdown]
# ## METHODS AND RESULTS

# %% [markdown]
# ### PRELIMINARY RESULTS

# %%
#Importing the libraries
library(tidyverse)
library(infer)
library(repr)
library(broom)
options(repr.plot.width=5, repr.plot.height=5)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.2 ──
# ✔ ggplot2 3.3.6      ✔ purrr   0.3.4
# ✔ tibble  3.1.8      ✔ dplyr   1.0.10
# ✔ tidyr   1.2.1      ✔ stringr 1.4.1
# ✔ readr   2.1.2      ✔ forcats 0.5.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
#Reading the data from the web
#Data is uploaded on github
crimedata_all_2018 <- read_csv(url("https://raw.githubusercontent.com/Krithik1/STAT_201_PROJECT/main/data/crimedata_csv_AllNeighbourhoods_2018.csv"))
crimedata_all_2020 <- read_csv(url("https://raw.githubusercontent.com/Krithik1/STAT_201_PROJECT/main/data/crimedata_csv_AllNeighbourhoods_2020.csv"))


head(crimedata_all_2018)
head(crimedata_all_2020)
# Out:
# Rows: 44280 Columns: 10
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (3): TYPE, HUNDRED_BLOCK, NEIGHBOURHOOD
# dbl (7): YEAR, MONTH, DAY, HOUR, MINUTE, X, Y
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 37516 Columns: 10
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (3): TYPE, HUNDRED_BLOCK, NEIGHBOURHOOD
# dbl (7): YEAR, MONTH, DAY, HOUR, MINUTE, X, Y
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#   TYPE                       YEAR MONTH DAY HOUR MINUTE HUNDRED_BLOCK
# 1 Break and Enter Commercial 2018  6    16  18    0     10XX ALBERNI ST
# 2 Break and Enter Commercial 2018 12    12   0    0     10XX BEACH AVE
# ...

# %% [markdown]
# ### Cleaning the Data

# %%
# Removing the columns MONTH, DAY, HOUR, MINUTE, HUNDRED_BLOCK, X and Y

crimedata_all_2018 <- select(crimedata_all_2018, c(1,2,8))
crimedata_all_2020 <- select(crimedata_all_2020, c(1,2,8))

head(crimedata_all_2018)
head(crimedata_all_2020)
# Out:
#   TYPE                       YEAR NEIGHBOURHOOD
# 1 Break and Enter Commercial 2018 West End
# 2 Break and Enter Commercial 2018 West End
# 3 Break and Enter Commercial 2018 Central Business District
# 4 Break and Enter Commercial 2018 Central Business District
# 5 Break and Enter Commercial 2018 Central Business District
# 6 Break and Enter Commercial 2018 Hastings-Sunrise
#   TYPE                       YEAR NEIGHBOURHOOD
# 1 Break and Enter Commercial 2020 West End
# 2 Break and Enter Commercial 2020 West End
# 3 Break and Enter Commercial 2020 West End
# 4 Break and Enter Commercial 2020 West End
# 5 Break and Enter Commercial 2020 West End
# 6 Break and Enter Commercial 2020 West End

# %% [markdown]
# ### Filtering the Data

# %%
# Extracting all theft-related crimes rows in the data set, which are Theft of Vehicle, Theft of Bicycle, Theft from Vehicle and Other Theft.

all_theft_2018 <- crimedata_all_2018 %>% filter(TYPE %in% c("Theft of Vehicle", "Theft of Bicycle", "Theft from Vehicle", "Other Theft"))
all_theft_2020 <- crimedata_all_2020 %>% filter(TYPE %in% c("Theft of Vehicle", "Theft of Bicycle", "Theft from Vehicle", "Other Theft"))
head(all_theft_2018)
nrow(all_theft_2018)
head(all_theft_2020)
nrow(all_theft_2020)
# Out:
#   TYPE        YEAR NEIGHBOURHOOD
# 1 Other Theft 2018 Central Business District
# 2 Other Theft 2018 Mount Pleasant
# 3 Other Theft 2018 West End
# 4 Other Theft 2018 West End
# 5 Other Theft 2018 West End
# 6 Other Theft 2018 West End
# [1] 29561
#   TYPE        YEAR NEIGHBOURHOOD
# 1 Other Theft 2020 West End
# 2 Other Theft 2020 West End
# 3 Other Theft 2020 West End
# 4 Other Theft 2020 West End
# 5 Other Theft 2020 West End
# 6 Other Theft 2020 West End
# [1] 21915

# %%
# Extracting rows which are in "Kitsilano" neighborhood

kitsilano_all_theft_2018 <- all_theft_2018 %>% filter(NEIGHBOURHOOD == "Kitsilano")
head(kitsilano_all_theft_2018)
nrow(kitsilano_all_theft_2018)
kitsilano_all_theft_2020 <- all_theft_2020 %>% filter(NEIGHBOURHOOD == "Kitsilano")
head(kitsilano_all_theft_2020)
nrow(kitsilano_all_theft_2020)
# Out:
#   TYPE        YEAR NEIGHBOURHOOD
# 1 Other Theft 2018 Kitsilano
# 2 Other Theft 2018 Kitsilano
# 3 Other Theft 2018 Kitsilano
# 4 Other Theft 2018 Kitsilano
# 5 Other Theft 2018 Kitsilano
# 6 Other Theft 2018 Kitsilano
# [1] 1393
#   TYPE        YEAR NEIGHBOURHOOD
# 1 Other Theft 2020 Kitsilano
# 2 Other Theft 2020 Kitsilano
# 3 Other Theft 2020 Kitsilano
# 4 Other Theft 2020 Kitsilano
# 5 Other Theft 2020 Kitsilano
# 6 Other Theft 2020 Kitsilano
# [1] 1135

# %%
#CALCULATING POPULATION PARAMETER
# p1: proportion of theft crimes in kitsilano in 2018
# p2: proportion of theft crimes in kitsilano in 2020
# p: difference in the proportions of theft crimes in Kitsilano in 2018 and 2020 (population parameter)

p1 <- nrow(kitsilano_all_theft_2018)/nrow(all_theft_2018)
p2 <- nrow(kitsilano_all_theft_2020)/nrow(all_theft_2020)
p <- p2-p1
p1
p2
p
# Out:
# [1] 0.0471229
# [1] 0.05179101
# [1] 0.004668112

# %%
# Creating table containing the proportions in both 2018 and 2020 and their difference (population)

pop_proportion_table <- tibble(p1 = p1, p2 = p2, p = p)

pop_proportion_table
# Out:
#   p1        p2         p
# 1 0.0471229 0.05179101 0.004668112

# %%
# Plotting the proportion of theft-related crimes in Kitsilano in both 2018 and 2020 using barplot (population)

barplot(c(p1, p2), main = "Figure 1: Proportion of theft crimes in Kitsilano in 2018\nand 2020", names.arg = c("p1", "p2"))
# Out:
# Plot with title “Figure 1: Proportion of theft crimes in Kitsilano in 2018
# and 2020”

# %%
# Plotting the total number of crimes for each type of theft-related crimes in 2018

kitsilano_theft_plot_type_2018 <- kitsilano_all_theft_2018 %>%
        group_by(TYPE) %>%
        summarise(count = n()) %>%
        ggplot() +
        geom_bar(aes(x = reorder(TYPE, -count), y = count), stat = "identity") +
        xlab("TYPE") +
        ggtitle("Figure 2: Kitsilano Theft TYPE Plot 2018")

kitsilano_theft_plot_type_2018
# Out:
# plot without title

# %%
# Plotting the total number of crimes for each type of theft-related crimes in 2020

kitsilano_theft_plot_type_2020 <- kitsilano_all_theft_2020 %>%
        group_by(TYPE) %>%
        summarise(count = n()) %>%
        ggplot() +
        geom_bar(aes(x = reorder(TYPE, -count), y = count), stat = "identity") +
        xlab("TYPE") +
        ggtitle("Figure 3: Kitsilano Theft TYPE Plot 2020")

kitsilano_theft_plot_type_2020
# Out:
# plot without title

# %%
# Taking samples of sample size 500 from both the datasets

set.seed(2)#Do not change
sample_size_both <- 500
all_theft_2018_sample <- rep_sample_n(all_theft_2018, size = sample_size_both)
all_theft_2020_sample <- rep_sample_n(all_theft_2020, size = sample_size_both)
head(all_theft_2018_sample)
head(all_theft_2020_sample)
# Out:
#   replicate TYPE               YEAR NEIGHBOURHOOD
# 1 1         Theft from Vehicle 2018 Strathcona
# 2 1         Theft from Vehicle 2018 Central Business District
# 3 1         Other Theft        2018 Renfrew-Collingwood
# 4 1         Other Theft        2018 Central Business District
# 5 1         Theft of Vehicle   2018 Riley Park
# 6 1         Theft of Vehicle   2018 Renfrew-Collingwood
#   replicate TYPE               YEAR NEIGHBOURHOOD
# 1 1         Other Theft        2020 Central Business District
# 2 1         Other Theft        2020 Mount Pleasant
# 3 1         Theft of Bicycle   2020 Renfrew-Collingwood
# 4 1         Other Theft        2020 Central Business District
# 5 1         Other Theft        2020 Central Business District
# 6 1         Theft from Vehicle 2020 Riley Park

# %%
# Combining both samples into a single dataset and simplifying that dataset

both_samples <- rbind(all_theft_2018_sample, all_theft_2020_sample)%>%
ungroup() %>%
mutate(NEIGHBOURHOOD = ifelse((NEIGHBOURHOOD=="Kitsilano"),"Kitsilano","Other Neighbourhood")) %>%
mutate(YEAR = as.factor(YEAR)) %>%
select(-c(replicate, TYPE))

head(both_samples)
# Out:
#   YEAR NEIGHBOURHOOD
# 1 2018 Other Neighbourhood
# 2 2018 Other Neighbourhood
# 3 2018 Other Neighbourhood
# 4 2018 Other Neighbourhood
# 5 2018 Other Neighbourhood
# 6 2018 Other Neighbourhood

# %%
# Calculating sample proportions
# p1_hat: proportion of theft crimes in kitsilano in 2018 in sample
# p2_hat: proportion of theft crimes in kitsilano in 2020 in sample
# p: difference in proportion of theft crimes in kitsilano in 2018 and 2020 in sample

p1_hat <- nrow(filter(all_theft_2018_sample, NEIGHBOURHOOD == "Kitsilano"))/nrow(all_theft_2018_sample)
p2_hat <- nrow(filter(all_theft_2020_sample, NEIGHBOURHOOD == "Kitsilano"))/nrow(all_theft_2020_sample)
p_hat <- p2_hat-p1_hat

p1_hat
p2_hat
p_hat
# Out:
# [1] 0.05
# [1] 0.068
# [1] 0.018

# %%
# Creating table containing the proportions in samples for both 2018 and 2020 and their difference 

sample_proportion_table <- tibble(p1_hat = p1_hat, p2_hat = p2_hat, p_hat = p_hat)
sample_proportion_table
# Out:
#   p1_hat p2_hat p_hat
# 1 0.05   0.068  0.018

# %%
# Plotting the proportion of theft-related crimes in Kitsilano in samples for both 2018 and 2020 using barplot

barplot(c(p1_hat, p2_hat), main = "Figure 4: Proportion of theft crimes in Kitsilano\nin 2018 and 2020 (Sample)", names.arg = c("p1_hat", "p2_hat"))
# Out:
# Plot with title “Figure 4: Proportion of theft crimes in Kitsilano
# in 2018 and 2020 (Sample)”

# %%
# Plotting the total number of crimes for each type of theft-related crimes in the 2018 sample

sample_kitsilano_theft_plot_type_2018 <- all_theft_2018_sample %>%
        filter(NEIGHBOURHOOD == "Kitsilano") %>%
        group_by(TYPE) %>%
        summarise(count = n()) %>%
        ggplot() +
        geom_bar(aes(x = reorder(TYPE, -count), y = count), stat = "identity") +
        xlab("TYPE") +
        ggtitle("Figure 5: Sample Kitsilano Theft TYPE Plot 2018")

sample_kitsilano_theft_plot_type_2018
# Out:
# plot without title

# %%
# Plotting the total number of crimes for each type of theft-related crimes in the 2020 sample

sample_kitsilano_theft_plot_type_2020 <- all_theft_2020_sample %>%
        filter(NEIGHBOURHOOD == "Kitsilano") %>%
        group_by(TYPE) %>%
        summarise(count = n()) %>%
        ggplot() +
        geom_bar(aes(x = reorder(TYPE, -count), y = count), stat = "identity") +
        xlab("TYPE") +
        ggtitle("Figure 6: Sample Kitsilano Theft TYPE Plot 2020")

sample_kitsilano_theft_plot_type_2020
# Out:
# plot without title

# %% [markdown]
# ### Plan

# %% [markdown]
# Our report is trustworthy because we've sampled from the population in a random, unbiased fashion (using rep_sample_n). Our samples are sufficiently large (500 each) so they're representative of the population. We've also set the seed, making our report reproducible. (Note: We'll pretend we don't have access to the entire population of crimes in Vancouver).
#
# We see an increase of 0.018 (1.8%) in our sample proportion from 2018 to 2020. However, this increase could result from sampling variability and may not indicate a real difference in population proportion. Therefore, we want to verify whether this increase is statistically significant.
#
# We intend to explore this using hypothesis testing. Since we have 2 samples from 2 independent populations (2018 and 2020), we'll use 2-sample z-testing (Krishnamoorthy & Thomson, 2002). We'll also construct a 90% confidence interval of the difference in proportions and check if it contains 0.
#
# We'll use a significance level of 10% (rather than 5%) because we feel like a type 2 error would be worse than a type 1 error in our report.
#
# As described above, we intend to use asymptotics for our analysis. However, if we get time, we will also use the bootstrapping method to validate our results.

# %% [markdown]
# #### Hypotheses:
# Our null hypothesis would be that the difference in the population proportion between 2020 and 2018 is 0, while our alternative hypothesis would be that this difference is greater than 0.
#
# H0: p2020-p2018 = 0
#
# Ha: p2020-p2018 > 0
#
# We'll use a right-tailed test.

# %% [markdown]
# ### CLT

# %% [markdown]
# 1. We use random sampling using rep_sample_n so both the samples are taken in a random and unbiased fashion
#
# 2. Both samples are independent of each other because they indicate thefts in Kitsilano in different years i.e. 2018 and 2020
#
# 3. Sample size (500) is large enough i.e (greater than 30)
#
# 4. We have 2 different populations i.e. Thefts in all neighbourhoods in 2018 and Thefts in all neighbourhoods in 2020
#
#     Population Size for year 2018 = 29561
#
#     Population Size for year 2020 = 21915
#
#     Sample Size for year 2018 = 500
#
#     Sample Size for year 2020 = 500
#
#     Both samples have sample size less than 10% of the population. Thus, we can assume that the sampling has been done independently
#
# 5. Testing np $\geq$ 10 and n(1-p) $\geq$ 10
#
#     Since, we have 2 independent populations we have to test the conditions for both of them
#
#     Population 1: Year 2018
#
#       n = 500
#
#       p = 0.05
#
#       np = 25 $\geq$ 10
#
#       n(1-p) = 475 $\geq$ 10
#
#
#     Population 2: Year 2020
#
#       n = 500
#
#       p = 0.068
#
#       np = 34 $\geq$ 10
#
#       n(1-p) = 466 $\geq$ 10

# %% [markdown]
# This means that we can use a normal approximation for the sampling distribution of the difference in sample proportions between 2020 and 2018

# %% [markdown]
# ### THEORY BASED METHOD (2 sample z testing)

# %%
# Testing the null hypothesis by calculating the p-value using prop.test

hypothesis_test <- tidy(
        prop.test(x = c(p2_hat * nrow(all_theft_2020_sample), p1_hat * nrow(all_theft_2018_sample)),
                  n = c(nrow(all_theft_2020_sample), nrow(all_theft_2018_sample)),
                  correct = FALSE,
                  alternative = "greater",
                  conf.level= 0.90))         

hypothesis_test
# Out:
#   estimate1 estimate2 statistic p.value   parameter conf.low    conf.high
# 1 0.068     0.05      1.45896   0.1135478 1         -0.00108402 1
#   method
# 1 2-sample test for equality of proportions without continuity correction
#   alternative
# 1 greater

# %% [markdown]
# ### INTERPRET RESULTS

# %% [markdown]
# The p-value is 0.1135 which is bigger than our significance level of 0.1
#
# Therefore, we fail to reject the null hypothesis i.e. we do not have sufficience evidence to conclude that the amount of thefts in Kitsilano increased between the years 2018 and 2020

# %% [markdown]
# ### CONSTRUCT CI (THEORY BASED)

# %%
# Define population mean and standard deviation
p_hat <- p2_hat-p1_hat
n1 <- 500
n2 <- 500
combined_p_hat <- (n1*p1_hat+n2*p2_hat)/(n1+n2)
theoretical_standard_error <- sqrt(combined_p_hat*(1-combined_p_hat)*(1/n1+1/n2))
theoretical_standard_error

x <- seq(p_hat-theoretical_standard_error*3.5, p_hat+theoretical_standard_error*3.5, length=1000)
y <- dnorm(x, mean=p_hat, sd=theoretical_standard_error)
plot(x, y, type="l", lwd=1, main = "Figure 7: ")
# Out:
# [1] 0.01490221
# Plot with title “Figure 7: ”

# %%
ggplot(data.frame(x = c(p_hat-theoretical_standard_error*3.5, p_hat+theoretical_standard_error*3.5)), aes(x = x)) +
        stat_function(fun = dnorm, args = list(mean = p_hat, sd = theoretical_standard_error)) +
        geom_vline(aes(xintercept = hypothesis_test$conf.low)) +
        geom_vline(aes(xintercept = hypothesis_test$conf.high)) +
        geom_vline(aes(xintercept = hypothesis_test$p.value)) +
        ggtitle("Figure 8: ")
# Out:
# plot without title

# %%
# Plotting the null model, test statistic and the critical region

normalDistribution <- data.frame(
    x = seq(-4,4, by = 0.01),
    y = dnorm(seq(-4,4, by = 0.01))
)

criticalValue <- qnorm(.90)

criticalValue

shadeNormal <- rbind(c(criticalValue,0), subset(normalDistribution, x > criticalValue), c(3,0))

ggplot(normalDistribution, aes(x,y)) +
    geom_line() +
    geom_polygon(data = shadeNormal, aes(x=x, y=y, fill="red")) +
    guides(fill="none") +
    geom_hline(yintercept = 0) +
    geom_segment(aes(x = criticalValue, y = 0, xend = criticalValue, yend = dnorm(criticalValue))) +
    geom_segment(aes(x = hypothesis_test$statistic, y = 0, xend = hypothesis_test$statistic, yend = dnorm(hypothesis_test$statistic))) +
    ggtitle("Figure 9: ")
# Out:
# [1] 1.281552
# plot without title

# %% [markdown]
# ### SIMULATION METHOD

# %%
# Building null model using simulation-based bootstrap method and calculate the p-value

set.seed(2)

# Generating a null distribution
bootstrap_method <- both_samples %>%
    specify(formula = NEIGHBOURHOOD ~ YEAR, success = "Kitsilano") %>%
    hypothesize(null = "independence") %>%
    generate(type = "bootstrap", reps =10000) %>%
    calculate(stat = "diff in props", order = c("2020", "2018"))

# Constructing confidence interval
ci<- bootstrap_method %>%
    group_by()%>%
    summarize(lower_ci = quantile(bootstrap_method$stat, 0.1), upper_ci = quantile(bootstrap_method$stat, 1))
ci

obs_stat_val <- p_hat
shift <- p_hat

# Plotting the null distribution
null_model <- bootstrap_method %>%
    mutate(stat = stat - shift)

null_model_plot <- null_model %>%
    visualize(bins = 20) +
    shade_ci(endpoints = ci) +
    shade_p_value(obs_stat = obs_stat_val, direction = "right") +
    ggtitle("Figure 10: Simulation-Based Null Distribution")
null_model_plot

# Calculating the p-value
null_model_p_value <- get_p_value(null_model, obs_stat = obs_stat_val, direction = "right")
null_model_p_value
# Out:
#   lower_ci     upper_ci
# 1 -0.001203008 0.08567173
#   p_value
# 1 0.1165
# plot without title

# %% [markdown]
# ### INTERPRET RESULTS

# %% [markdown]
# The p-value is 0.1165 which is bigger than our significance level of 0.1
#
# Therefore, we fail to reject the null hypothesis i.e. we do not have sufficient evidence to conclude that the amount of thefts in Kitsilano increased between the years 2018 and 2020

# %% [markdown]
# ### CONSTRUCT CI (SIMULATION BASED) (PERCENTILE METHOD)

# %% [markdown]
# ## DISCUSSION

# %% [markdown]
# ### COMPARE RESULTS

# %% [markdown]
# Our analysis using the theory based method (2 sample z testing) and the simulated bootstrap method yielded the p-values 0.1135 and 0.1165 respectively, which are both greater than our significance level of 10% (0.10). As such, our results were not statistically significant and we fail to reject the null hypothesis. Thus, we do not have sufficient evidence to conclude that the proportion of theft crimes increased in Kitsilano during the pandemic. We did not expect this result, as the SFU study concluded that theft-related crimes increased in wealthier neighbours during the pandemic. One reason for this result could be due to the fact that the pandemic did not start until the middle of March 2020, so crime data for January and February 2020 contained "normal" crime rates. This could have influenced our sample proportion for 2020, which we calculated assuming all months of 2020 were under the pandemic, making it more similar to our sample proportion for 2018 than we intended. If we repeat this analysis in the future, we should only sample from 2020 data taken after the pandemic was declared, and only sample from 2018 days which are also included in the 2020 pandemic data. We could also increase the statistical power of our test to increase our probability of correctly rejecting the null hypothesis when it is false. For example, if we increase our sample size, the power will increase and our p-values may be smaller, allowing us to reject the null hypothesis if it's smaller than our significance level.
#
# A future question this study could lead to would be whether other wealthy neighbourhoods in Vancouver (such as Oakridge) experienced similar trends in theft-related crimes as Kitsilano before and during the pandemic. We could also explore the pandemic's impact on theft-related crimes on Vancouver's poorer neighbourhoods, and see if they were any different from the wealthier areas. Additionally, we could explore the pandemic's impact on various neighbourhoods in Vancouver for other types of crime, such as mischief or assault.

# %% [markdown]
# ## REFERENCES

# %% [markdown]
# - Krishnamoorthy, K., &amp; Thomson, J. (2002). Hypothesis testing about proportions in two finite populations. The American Statistician, 56(3), 215–222. https://doi.org/10.1198/000313002164
#
# - Andresen, M. A., &amp; Hodgkinson, T. (2022, January 9). In a world called catastrophe: The impact of covid-19 on neighbourhood level crime in Vancouver, Canada. Journal of experimental criminology. Retrieved November 4, 2022, from https://www.ncbi.nlm.nih.gov/pmc/articles/PMC8742714/
#
# - Data is from: VPD open data. (n.d.). Retrieved November 4, 2022, from https://geodash.vpd.ca/opendata/
